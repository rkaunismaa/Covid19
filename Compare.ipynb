# %% [markdown]
# Let's compare one spreadsheet to the other and see if any of the same records that exist between the 2 have changed.

# %%
import numpy as np
import pandas as pd

np.__version__, pd.__version__
# ('1.19.2', '1.2.2')
# Out:
# ('1.19.2', '1.2.2')

# %%
csvName = 'COVID19-eng-2021-03-04'
csvFileName = 'data/' +  csvName + '.csv'
covid19A = pd.read_csv(csvFileName, header=0, index_col='Case identifier number')

# %%
csvName = 'COVID19-eng-Fixed'
csvFileName = 'data/' +  csvName + '.csv'
covid19B = pd.read_csv(csvFileName, header=0, index_col='Case identifier number')

# %%
covid19A.head(10)
# Out:
#                         Region  Episode week  Episode week group  \
# Case identifier number
# 1                            3             2                   0
# 2                            2             3                   0
# 3                            2             3                   0
# 4                            3            35                   0
# 5                            2            46                   0
# 6                            2            52                   0
# 7                            3            39                   0
# 8                            3            42                   0
# 9                            2            52                   0
# 10                           2             7                   0
#
#                         Episode year  Gender  Age group  Occupation  \
# Case identifier number
# 1                                 21       1          2           9
# ...

# %%
covid19A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 839926 entries, 1 to 839926
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Region                  839926 non-null  int64
#  1   Episode week            839926 non-null  int64
#  2   Episode week group      839926 non-null  int64
#  3   Episode year            839926 non-null  int64
#  4   Gender                  839926 non-null  int64
#  5   Age group               839926 non-null  int64
#  6   Occupation              839926 non-null  int64
#  7   Asymptomatic            839926 non-null  int64
#  8   Onset week of symptoms  839926 non-null  int64
#  9   Onset year of symptoms  839926 non-null  int64
#  10  Hospital status         839926 non-null  int64
#  11  Recovered               839926 non-null  int64
#  12  Recovery week           839926 non-null  int64
#  13  Recovery year           839926 non-null  int64
# ...

# %%
covid19B.head(10)
# Out:
#                         Region  Episode week  Episode week group  \
# Case identifier number
# 1                            3            52                   0
# 2                            2             1                   0
# 3                            2             1                   0
# 4                            2            45                   0
# 5                            4            52                   0
# 6                            2            50                   0
# 7                            3            42                   0
# 8                            2            51                   0
# 9                            3            15                   0
# 10                           3             1                   0
#
#                         Episode year  Gender  Age group  Occupation  \
# Case identifier number
# 1                                 20       1          6           9
# ...

# %%
covid19B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 666237 entries, 1 to 666237
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Region                        666237 non-null  int64
#  1   Episode week                  666237 non-null  int64
#  2   Episode week group            666237 non-null  int64
#  3   Episode year                  666237 non-null  int64
#  4   Gender                        666237 non-null  int64
#  5   Age group                     666237 non-null  int64
#  6   Occupation                    666237 non-null  int64
#  7   Asymptomatic                  666237 non-null  int64
#  8   Onset week of symptoms        666237 non-null  int64
#  9   Onset year of symptoms        666237 non-null  int64
#  10  Symptom, cough                666237 non-null  int64
#  11  Symptom, fever                666237 non-null  int64
# ...
